# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

print('19~20년 국내해외여행객 증감추이')
print()
a = open('해외여행 01월.csv', encoding = 'cp949')
data = csv.reader(a)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202001 = i[2]
        c201901 = i[3]
        print('19년도 1월 : ',c201901,'\t','20년도 1월 : ',c202001)

a2 = open('해외여행 02월.csv', encoding = 'cp949')
data = csv.reader(a2)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202002 = i[2]
        c201902 = i[3]
        print('19년도 2월 : ',c201902,'\t','20년도 2월 : ',c202002)

a3 = open('해외여행 03월.csv', encoding = 'cp949')
data = csv.reader(a3)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202003 = i[2]
        c201903 = i[3]
        print('19년도 3월 : ',c201903,'\t','20년도 3월 : ',c202003)

a4 = open('해외여행 04월.csv', encoding = 'cp949')
data = csv.reader(a4)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202004 = i[2]
        c201904 = i[3]
        print('19년도 4월 : ',c201904,'\t','20년도 4월 : ',c202004)
        
a5 = open('해외여행 05월.csv', encoding = 'cp949')
data = csv.reader(a5)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202005 = i[2]
        c201905 = i[3]
        print('19년도 5월 : ',c201905,'\t','20년도 5월 : ',c202005)

a6 = open('해외여행 06월.csv', encoding = 'cp949')
data = csv.reader(a6)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202006 = i[2]
        c201906 = i[3]
        print('19년도 6월 : ',c201906,'\t','20년도 6월 : ',c202006)
        
a7 = open('해외여행 07월.csv', encoding = 'cp949')
data = csv.reader(a7)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202007 = i[2]
        c201907 = i[3]
        print('19년도 7월 : ',c201907,'\t','20년도 7월 : ',c202007)
        
a8 = open('해외여행 08월.csv', encoding = 'cp949')
data = csv.reader(a8)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202008 = i[2]
        c201908 = i[3]
        print('19년도 8월 : ',c201908,'\t','20년도 8월 : ',c202008)
        
a9 = open('해외여행 09월.csv', encoding = 'cp949')
data = csv.reader(a9)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202009 = i[2]
        c201909 = i[3]
        print('19년도 9월 : ',c201909,'\t','20년도 9월 : ',c202009)
        
a10 = open('해외여행 10월.csv', encoding = 'cp949')
data = csv.reader(a10)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202010 = i[2]
        c201910 = i[3]
        print('19년도 10월 : ',c201910,'\t','20년도 10월 : ',c202010)
        
a11 = open('해외여행 11월.csv', encoding = 'cp949')
data = csv.reader(a11)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202011 = i[2]
        c201911 = i[3]
        print('19년도 11월 : ',c201911,'\t','20년도 11월 : ',c202011)
        
a12 = open('해외여행 12월.csv', encoding = 'cp949')
data = csv.reader(a12)
header = next(data)

for i in data:
    if '국민' in i[0]:
        c202012 = i[2]
        c201912 = i[3]
        print('19년도 12월 : ',c201912,'\t','20년도 12월 : ',c202012)

print()
# Out:
# 19~20년 국내해외여행객 증감추이
#
# 19년도 1월 :  2,912,331 	 20년도 1월 :  2,513,030
# 19년도 2월 :  2,617,946 	 20년도 2월 :  1,046,779
# 19년도 3월 :  2,334,153 	 20년도 3월 :  143,366
# 19년도 4월 :  2,246,417 	 20년도 4월 :  31,425
# 19년도 5월 :  2,401,204 	 20년도 5월 :  37,802
# 19년도 6월 :  2,495,798 	 20년도 6월 :  48,353
# 19년도 7월 :  2,642,585 	 20년도 7월 :  65,936
# 19년도 8월 :  2,427,634 	 20년도 8월 :  88,888
# 19년도 9월 :  2,049,830 	 20년도 9월 :  76,798
# 19년도 10월 :  2,153,847 	 20년도 10월 :  71,970
# 19년도 11월 :  2,090,192 	 20년도 11월 :  70,686
# 19년도 12월 :  2,342,310 	 20년도 12월 :  80,973
