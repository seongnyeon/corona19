# %%
import csv
import matplotlib.pyplot as plt
import numpy as np 
import matplotlib.ticker as ticker 

print('19~20년 제주여행객 증감추이')

b1 = open('제주여행 01월.csv', encoding = 'cp949')
data = csv.reader(b1)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202001 = i[4]
        j201901 = i[5]
        print('19년도 01월 : ',j201901,'\t','20년도 01월 : ',j202001)

b2 = open('제주여행 02월.csv', encoding = 'cp949')
data = csv.reader(b2)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202002 = i[4]
        j201902 = i[5]
        print('19년도 02월 : ',j201902,'\t\t','20년도 02월 : ',j202002)

b3 = open('제주여행 03월.csv', encoding = 'cp949')
data = csv.reader(b3)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202003 = i[4]
        j201903 = i[5]
        print('19년도 03월 : ',j201903,'\t','20년도 03월 : ',j202003)
        
b4 = open('제주여행 04월.csv', encoding = 'cp949')
data = csv.reader(b4)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202004 = i[4]
        j201904 = i[5]
        print('19년도 04월 : ',j201904,'\t','20년도 04월 : ',j202004)
        
b5 = open('제주여행 05월.csv', encoding = 'cp949')
data = csv.reader(b5)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202005 = i[4]
        j201905 = i[5]
        print('19년도 05월 : ',j201905,'\t','20년도 05월 : ',j202005)
        
b6 = open('제주여행 06월.csv', encoding = 'cp949')
data = csv.reader(b6)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202006 = i[4]
        j201906 = i[5]
        print('19년도 06월 : ',j201906,'\t','20년도 06월 : ',j202006)
        
b7 = open('제주여행 07월.csv', encoding = 'cp949')
data = csv.reader(b7)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202007 = i[4]
        j201907 = i[5]
        print('19년도 07월 : ',j201907,'\t','20년도 07월 : ',j202007)
        
b8 = open('제주여행 08월.csv', encoding = 'cp949')
data = csv.reader(b8)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202008 = i[4]
        j201908 = i[5]
        print('19년도 08월 : ',j201908,'\t','20년도 08월 : ',j202008)
        
b9 = open('제주여행 09월.csv', encoding = 'cp949')
data = csv.reader(b9)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202009 = i[4]
        j201909 = i[5]
        print('19년도 09월 : ',j201909,'\t','20년도 09월 : ',j202009)
        
b10 = open('제주여행 10월.csv', encoding = 'cp949')
data = csv.reader(b10)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202010 = i[4]
        j201910 = i[5]
        print('19년도 10월 : ',j201910,'\t','20년도 10월 : ',j202010)
        
b11 = open('제주여행 11월.csv', encoding = 'cp949')
data = csv.reader(b11)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202011 = i[4]
        j201911 = i[5]
        print('19년도 11월 : ',j201911,'\t','20년도 11월 : ',j202011)
        
b12 = open('제주여행 12월.csv', encoding = 'cp949')
data = csv.reader(b12)
header = next(data)

for i in data:
    if '내국인' in i[0]:
        j202012 = i[4]
        j201912 = i[5]
        print('19년도 12월 : ',j201912,'\t','20년도 12월 : ',j202012)
        
N = 12
year2019 = (1024130, 998890, 1038223, 1158666, 1176059, 1155020, 1157447, 1243132, 1032478, 1254419, 1177768, 1143772) 
year2020 = (1104438, 599575, 477176, 541099, 765616, 860528, 988094, 1127097, 726169, 1072455, 1138369, 623062) 
ind = np.arange(N) 
width = 0.3 

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

ax = plt.axes() 
ax.yaxis.set_major_locator(ticker.MultipleLocator(100000)) 
ax.yaxis.set_minor_locator(ticker.MultipleLocator(10000)) 
plt.grid(which='major', linewidth = '0.8', axis = 'y') 
plt.grid(which='minor', linewidth = '0.3', axis = 'y') 

plt.ylabel("단위: 명", fontsize=12) 
plt.title("19~20년 제주여행객 증감추이", fontsize = 20, color='k') 

p1 = plt.bar(ind-0.2, year2019, width) 
p2 = plt.bar(ind+0.2, year2020, width) 
plt.legend((p1[0], p2[0]), ('2019', '2020')) 
plt.xticks(ind, ('01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12')) 


plt.show()
# Out:
# 19~20년 제주여행객 증감추이
# 19년도 01월 :  1,024,130 	 20년도 01월 :  1,104,438
# 19년도 02월 :  998,890 		 20년도 02월 :  599,575
# 19년도 03월 :  1,038,223 	 20년도 03월 :  477,176
# 19년도 04월 :  1,158,666 	 20년도 04월 :  541,099
# 19년도 05월 :  1,176,059 	 20년도 05월 :  765,616
# 19년도 06월 :  1,155,020 	 20년도 06월 :  860,528
# 19년도 07월 :  1,157,447 	 20년도 07월 :  988,094
# 19년도 08월 :  1,243,132 	 20년도 08월 :  1,127,097
# 19년도 09월 :  1,032,478 	 20년도 09월 :  726,169
# 19년도 10월 :  1,254,419 	 20년도 10월 :  1,072,455
# 19년도 11월 :  1,177,768 	 20년도 11월 :  1,138,369
# 19년도 12월 :  1,143,772 	 20년도 12월 :  623,062
